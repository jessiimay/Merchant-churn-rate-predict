# %%
import numpy as np
import pandas as pd
EIGEN = "特征值/eigen_train.csv"
# EIGEN_TEST = "特征值/eigen_test.csv"
eigen= pd.read_csv(EIGEN, engine='python')

# %%
eigen.drop(columns='Unnamed: 0',inplace=True)

# %%
title = eigen.columns
title = title.values.tolist()
title.remove('lost')

# %%
title
# Out:
# ['store_id',
#  'discount',
#  'industry_level1',
#  'province',
#  'price_reduced_rate',
#  'reduce_range',
#  'pay_rate',
#  'success_rate',
#  'operate_state',
#  'daily_amount',
#  'daily_count',
#  'original_amount',
#  'payw_offer']

# %%
eigen.drop(columns=['lost'],inplace=True)

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")
# for i in range(1,len(title)):
sns.violinplot( data=eigen.iloc[:,1])

# %%
sns.barplot(x=eigen['industry_level1'])

# %%
sns.violinplot( data=eigen.iloc[:,2])

# %%
sns.violinplot( data=eigen.iloc[:,3])

# %%
sns.violinplot( data=eigen.iloc[:,4])

# %%
sns.violinplot( data=eigen.iloc[:,5])

# %%
sns.violinplot( data=eigen.iloc[:,6])

# %%
sns.violinplot( data=eigen.iloc[:,7])

# %%
sns.violinplot( data=eigen.iloc[:,8])

# %%
sns.violinplot( data=eigen.iloc[:,9])

# %%
sns.violinplot( data=eigen.iloc[:,10])

# %%
    #设置聚类热图颜色
    #1.一种颜色
    #如果整个图片只显示一种颜色的梯度的话
g = sns.clustermap(eigen.drop(columns=['store_id']), metric="correlation",method="single", center=0,cmap="vlag",figsize=(13,13), robust=True,z_score=1) #绘图
# g = sns.clustermap(eigen.drop(columns=['store_id']),cmap="Greens") #绿色jxu

# %%
    #设置聚类热图颜色
    #1.一种颜色
    #如果整个图片只显示一种颜色的梯度的话
g = sns.clustermap(eigen.drop(columns=['store_id']), metric="correlation",method="single", center=0,cmap="vlag",figsize=(13,13), robust=True,standard_scale=1) #绘图
# g = sns.clustermap(eigen.drop(columns=['store_id']),cmap="Greens") #绿色jxu

# %%
    #设置聚类热图颜色
    #1.一种颜色
    #如果整个图片只显示一种颜色的梯度的话
g = sns.clustermap(eigen.drop(columns=['store_id']).corr(),cmap="mako") #绘图

# %%
    #设置聚类热图颜色
    #1.一种颜色
    #如果整个图片只显示一种颜色的梯度的话
g = sns.heatmap(eigen.drop(columns=['store_id']).corr(),cmap="vlag",center=0) #绘图
